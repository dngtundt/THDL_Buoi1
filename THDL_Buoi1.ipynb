# %% [markdown]
# <a href="https://colab.research.google.com/github/dngtundt/THDL_Buoi1/blob/main/THDL_Buoi1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #include <conio.h>
#
# Object — Đối tượng
#
# Đối tượng: thuộc tính
#
# phương thức
#
# ???
# D = [PHAN TU 1, PHAN TU 2]
#
# Phan tu 1: [ ], [ ]
#
# Phan tu 2: [ ], [ ]
#
# 1.1; [x, x, x]
#
# numpy
#
# pandas
#
# tensor
#
# 1.
#
# 2.
#
# List —> numpy —> pandas
#
# []
#
# frame
#
# Khung
#
# cột và dòng
#
# Tên cột
#
# dòng: indexing
#
# dataframe
#
# Import pandas as pd
#
# Tử điển: {“key1”: value1”, “key2”: value2”}

# %%
import numpy as np

# cách 1
# tạo list
my_list = [1, 9, 15, 39]
print('Python list:', my_list)

# chuyển list --> Numpy array
my_numpy_array = np.array(my_list)
print('Numpy array:', my_numpy_array)

# cách 2
a = np.array([1, 9, 15, 39])
print(a)
# Out:
# Python list: [1, 9, 15, 39]
# Numpy array: [ 1  9 15 39]
# [ 1  9 15 39]
